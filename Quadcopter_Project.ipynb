# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import MyTask

# Modify the values below to give the quadcopter a different starting position.
runtime = 10.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = MyTask(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [ 10.41146814 -59.05235144   0.           5.03770901   5.7873824
#    0.        ]
# [  5.06474262 -30.00468704 -39.03891175]
# [-0.19810671 -0.05105369  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import MyTask

num_episodes = 10 # original value: 1000
target_pos = np.array([0., 0., 10.])
task = MyTask(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-05c6974b2be3> in <module>()
#       1 import sys
#       2 import pandas as pd
# ----> 3 from agents.policy_search import PolicySearch_Agent
#       4 from task import MyTask
#       5
#
# ~/Documents/jnotebooks/Udacity_ML/RL-Quadcopter-2/agents/policy_search.py in <module>()
#       1 import numpy as np
# ----> 2 from task import Task
#       3
#       4 class PolicySearch_Agent():
#       5     def __init__(self, task):
#
# ImportError: cannot import name 'Task'

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
## TODO: Train your agent here.

# %%
# import random
# from collections import namedtuple, deque

# class ReplayBuffer:
#     """Fixed-size buffer to store experience tuples."""

#     def __init__(self, buffer_size, batch_size):
#         """Initialize a ReplayBuffer object.
#         Params
#         ======
#             buffer_size: maximum size of buffer
#             batch_size: size of each training batch
#         """
#         self.memory = deque(maxlen=buffer_size)  # internal memory (deque)
#         self.batch_size = batch_size
#         self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])

#     def add(self, state, action, reward, next_state, done):
#         """Add a new experience to memory."""
#         e = self.experience(state, action, reward, next_state, done)
#         self.memory.append(e)

#     def sample(self, batch_size=64):
#         """Randomly sample a batch of experiences from memory."""
#         return random.sample(self.memory, k=self.batch_size)

#     def __len__(self):
#         """Return the current size of internal memory."""
#         return len(self.memory)

# %%
# from keras import layers, models, optimizers
# from keras import backend as K

# class Actor:
#     """Actor (Policy) Model."""

#     def __init__(self, state_size, action_size, action_low, action_high):
#         """Initialize parameters and build model.

#         Params
#         ======
#             state_size (int): Dimension of each state
#             action_size (int): Dimension of each action
#             action_low (array): Min value of each action dimension
#             action_high (array): Max value of each action dimension
#         """
#         self.state_size = state_size
#         self.action_size = action_size
#         self.action_low = action_low
#         self.action_high = action_high
#         self.action_range = self.action_high - self.action_low

#         # Initialize any other variables here

#         self.build_model()

#     def build_model(self):
#         """Build an actor (policy) network that maps states -> actions."""
#         # Define input layer (states)
#         states = layers.Input(shape=(self.state_size,), name='states')

#         # Add hidden layers
#         net = layers.Dense(units=32, activation='relu')(states)
#         net = layers.Dense(units=64, activation='relu')(net)
#         net = layers.Dense(units=32, activation='relu')(net)

#         # Try different layer sizes, activations, add batch normalization, regularizers, etc.

#         # Add final output layer with sigmoid activation
#         raw_actions = layers.Dense(units=self.action_size, activation='sigmoid',
#             name='raw_actions')(net)

#         # Scale [0, 1] output for each action dimension to proper range
#         actions = layers.Lambda(lambda x: (x * self.action_range) + self.action_low,
#             name='actions')(raw_actions)

#         # Create Keras model
#         self.model = models.Model(inputs=states, outputs=actions)

#         # Define loss function using action value (Q value) gradients
#         action_gradients = layers.Input(shape=(self.action_size,))
#         loss = K.mean(-action_gradients * actions)

#         # Incorporate any additional losses here (e.g. from regularizers)

#         # Define optimizer and training function
#         optimizer = optimizers.Adam()
#         updates_op = optimizer.get_updates(params=self.model.trainable_weights, loss=loss)
#         self.train_fn = K.function(
#             inputs=[self.model.input, action_gradients, K.learning_phase()],
#             outputs=[],
#             updates=updates_op)

# %%
# class Critic:
#     """Critic (Value) Model."""

#     def __init__(self, state_size, action_size):
#         """Initialize parameters and build model.

#         Params
#         ======
#             state_size (int): Dimension of each state
#             action_size (int): Dimension of each action
#         """
#         self.state_size = state_size
#         self.action_size = action_size

#         # Initialize any other variables here

#         self.build_model()

#     def build_model(self):
#         """Build a critic (value) network that maps (state, action) pairs -> Q-values."""
#         # Define input layers
#         states = layers.Input(shape=(self.state_size,), name='states')
#         actions = layers.Input(shape=(self.action_size,), name='actions')

#         # Add hidden layer(s) for state pathway
#         net_states = layers.Dense(units=32, activation='relu')(states)
#         net_states = layers.Dense(units=64, activation='relu')(net_states)

#         # Add hidden layer(s) for action pathway
#         net_actions = layers.Dense(units=32, activation='relu')(actions)
#         net_actions = layers.Dense(units=64, activation='relu')(net_actions)

#         # Try different layer sizes, activations, add batch normalization, regularizers, etc.

#         # Combine state and action pathways
#         net = layers.Add()([net_states, net_actions])
#         net = layers.Activation('relu')(net)

#         # Add more layers to the combined network if needed

#         # Add final output layer to prduce action values (Q values)
#         Q_values = layers.Dense(units=1, name='q_values')(net)

#         # Create Keras model
#         self.model = models.Model(inputs=[states, actions], outputs=Q_values)

#         # Define optimizer and compile model for training with built-in loss function
#         optimizer = optimizers.Adam()
#         self.model.compile(optimizer=optimizer, loss='mse')

#         # Compute action gradients (derivative of Q values w.r.t. to actions)
#         action_gradients = K.gradients(Q_values, actions)

#         # Define an additional function to fetch action gradients (to be used by actor model)
#         self.get_action_gradients = K.function(
#             inputs=[*self.model.input, K.learning_phase()],
#             outputs=action_gradients)

# %%
# class DDPG():
#     """Reinforcement Learning agent that learns using DDPG."""
#     def __init__(self, task):
#         self.task = task
#         self.state_size = task.state_size
#         self.action_size = task.action_size
#         self.action_low = task.action_low
#         self.action_high = task.action_high

#         # Actor (Policy) Model
#         self.actor_local = Actor(self.state_size, self.action_size, self.action_low, self.action_high)
#         self.actor_target = Actor(self.state_size, self.action_size, self.action_low, self.action_high)

#         # Critic (Value) Model
#         self.critic_local = Critic(self.state_size, self.action_size)
#         self.critic_target = Critic(self.state_size, self.action_size)

#         # Initialize target model parameters with local model parameters
#         self.critic_target.model.set_weights(self.critic_local.model.get_weights())
#         self.actor_target.model.set_weights(self.actor_local.model.get_weights())

#         # Noise process
#         self.exploration_mu = 0
#         self.exploration_theta = 0.15
#         self.exploration_sigma = 0.2
#         self.noise = OUNoise(self.action_size, self.exploration_mu, self.exploration_theta, self.exploration_sigma)

#         # Replay memory
#         self.buffer_size = 100000
#         self.batch_size = 64
#         self.memory = ReplayBuffer(self.buffer_size, self.batch_size)

#         # Algorithm parameters
#         self.gamma = 0.99  # discount factor (Udacity: 0.99)
#         self.tau = 0.01  # for soft update of target parameters (Udacity: 0.01)
        
#         # Score tracker and learning parameters
# #         self.best_score = -np.inf
#         self.counter = 0

#     def reset_episode(self):
#         self.noise.reset()
#         state = self.task.reset()
#         self.last_state = state
#         return state

#     def step(self, action, reward, next_state, done):
#          # Save experience / reward
#         self.memory.add(self.last_state, action, reward, next_state, done)

#         # Learn, if enough samples are available in memory
#         if len(self.memory) > self.batch_size:
#             experiences = self.memory.sample()
#             self.learn(experiences)

#         # Roll over last state and action
#         self.last_state = next_state

#     def act(self, state):
#         """Returns actions for given state(s) as per current policy."""
#         state = np.reshape(state, [-1, self.state_size])
#         action = self.actor_local.model.predict(state)[0]
#         return list(action + self.noise.sample())  # add some noise for exploration

#     def learn(self, experiences):
#         """Update policy and value parameters using given batch of experience tuples."""
#         # Convert experience tuples to separate arrays for each element (states, actions, rewards, etc.)
#         states = np.vstack([e.state for e in experiences if e is not None])
#         actions = np.array([e.action for e in experiences if e is not None]).astype(np.float32).reshape(-1, self.action_size)
#         rewards = np.array([e.reward for e in experiences if e is not None]).astype(np.float32).reshape(-1, 1)
#         dones = np.array([e.done for e in experiences if e is not None]).astype(np.uint8).reshape(-1, 1)
#         next_states = np.vstack([e.next_state for e in experiences if e is not None])

#         # Get predicted next-state actions and Q values from target models
#         #     Q_targets_next = critic_target(next_state, actor_target(next_state))
#         actions_next = self.actor_target.model.predict_on_batch(next_states)
#         Q_targets_next = self.critic_target.model.predict_on_batch([next_states, actions_next])

#         # Compute Q targets for current states and train critic model (local)
#         Q_targets = rewards + self.gamma * Q_targets_next * (1 - dones)
#         self.critic_local.model.train_on_batch(x=[states, actions], y=Q_targets)

#         # Train actor model (local)
#         action_gradients = np.reshape(self.critic_local.get_action_gradients([states, actions, 0]), (-1, self.action_size))
#         self.actor_local.train_fn([states, action_gradients, 1])  # custom training function

#         # Soft-update target models
#         self.soft_update(self.critic_local.model, self.critic_target.model)
#         self.soft_update(self.actor_local.model, self.actor_target.model)   

#     def soft_update(self, local_model, target_model):
#         """Soft update model parameters."""
#         local_weights = np.array(local_model.get_weights())
#         target_weights = np.array(target_model.get_weights())

#         assert len(local_weights) == len(target_weights), "Local and target model parameters must have the same size"

#         new_weights = self.tau * local_weights + (1 - self.tau) * target_weights
#         target_model.set_weights(new_weights)

# %%
# import numpy as np
# import copy

# class OUNoise:
#     """Ornstein-Uhlenbeck process."""

#     def __init__(self, size, mu, theta, sigma):
#         """Initialize parameters and noise process."""
#         self.mu = mu * np.ones(size)
#         self.theta = theta
#         self.sigma = sigma
#         self.reset()

#     def reset(self):
#         """Reset the internal state (= noise) to mean (mu)."""
#         self.state = copy.copy(self.mu)

#     def sample(self):
#         """Update internal state and return it as a noise sample."""
#         x = self.state
#         dx = self.theta * (self.mu - x) + self.sigma * np.random.randn(len(x))
#         self.state = x + dx
#         return self.state

# %%
from decimal import Decimal

def floatToDecimal(fnumber, dec=2):
    x = Decimal(fnumber)
    return round(x, 2)

# %%
# import math

# def euclideanDistance(p, q):
#     '''Calculates euclidean distance between two points in nth dimension'''
#     n = len(p)
#     sums = 0
#     for i in range(n):
#         sums += (p[i] - q[i]) ** 2
#     dist = math.sqrt(sums)
#     return dist

#     def get_reward(self):
#         """My own reward."""

# %%
# import numpy as np
# from physics_sim import PhysicsSim


# class MyTask(): 
#     """Task (environment) that defines the goal and provides feedback to the agent."""
    
#     def __init__(self, init_pose=None, init_velocities=None, 
#         init_angle_velocities=None, runtime=5., target_pos=None):
#         """Initialize a Task object.
#         Params
#         ======
#             init_pose: initial position of the quadcopter in (x,y,z) dimensions and the Euler angles
#             init_velocities: initial velocity of the quadcopter in (x,y,z) dimensions
#             init_angle_velocities: initial radians/second for each of the three Euler angles
#             runtime: time limit for each episode
#             target_pos: target/goal (x,y,z) position for the agent
#         """
#         # Simulation
#         self.sim = PhysicsSim(init_pose, init_velocities, init_angle_velocities, runtime) 
#         self.action_repeat = 3

#         self.state_size = self.action_repeat * 6
#         self.action_low = 0
#         self.action_high = 900
#         self.action_size = 4
#         self.crash = False

#         # Goal
#         self.target_pos = target_pos if target_pos is not None else np.array([0., 0., 10.]) 

#     # Original rewards function by Udacity
# #     def get_reward(self):
# #         """Uses current pose of sim to return reward."""
# #         reward = 1.-.3*(abs(self.sim.pose[:3] - self.target_pos)).sum()
# #         return reward
    
#     def get_reward(self):
#         """My own reward."""

# #         reward = 1. - .3 * (abs(self.sim.pose[:3] - self.target_pos)).sum() # Udacity
# #         reward = np.tanh(1. - .3 * (abs(self.sim.pose[:3] - self.target_pos))).sum()
#         reward = np.tanh(1. - 0.003*(abs(self.sim.pose[:3] - self.target_pos))).sum()
        
# #         #detect crash
#         if ((self.sim.pose[2] == 0) and (abs(self.sim.v[2]) > 2.)):
#             self.crash = True
#             self.counter = 0
                  
#         return reward

    
#     def step(self, rotor_speeds):
#         """Uses action to obtain next state, reward, done."""
        
#         reward = 0
#         pose_all = []
#         for _ in range(self.action_repeat):
#             done = self.sim.next_timestep(rotor_speeds) # update the sim pose and velocities
#             reward += self.get_reward() 
#             pose_all.append(self.sim.pose)
#         next_state = np.concatenate(pose_all)
#         return next_state, reward, done

#     def reset(self):
#         """Reset the sim to start a new episode."""
#         self.sim.reset()
#         self.crash = False
#         state = np.concatenate([self.sim.pose] * self.action_repeat) 
#         return state

# %%
from task import MyTask
from agents.agent import DDPG

num_episodes = 1000  # original value: 1000
runtime = 10.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])
target_pos = np.array([0., 0., 10.])     # Task is to hover in the same place
task = MyTask(init_pose=init_pose, target_pos=target_pos, runtime=runtime)
# agent = PolicySearch_Agent(task) 
agent = DDPG(task) 

episode_rewards = []
times = []
crashes = []

for i_episode in range(1, num_episodes+1):
    print("\n______________________________________________________________________\n")
    print(f'Episode: {i_episode}\n')
    
    state = agent.reset_episode() # start a new episode
    
    rewards = []
    
    
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        rewards.append(reward)
#       DDPG:  def step(self, action, reward, next_state, done):
        agent.step(action, reward, next_state, done)
        state = next_state
        if done:
            total_reward = sum(rewards)
            episode_rewards.append(total_reward)
            times.append(task.sim.time / runtime)
            crashes.append(task.crash)
#             print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
#                 i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
#            print(f'Episode: {i_episode}\n')  # [debug]
            break
      
    print(f't={floatToDecimal(task.sim.time)}, r={total_reward:.2}, crash={task.crash}')    
    
    if agent.counter >= 5:      # stop learning after 5 successful attempts
        break
        
    sys.stdout.flush()
    
# plt.plot(episode_rewards)
# Out:
# Using TensorFlow backend.
# ______________________________________________________________________
#
# Episode: 1
#
# t=1.38, r=1.4e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 2
#
# t=1.38, r=1.4e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 3
#
# t=1.38, r=1.4e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 4
#
# t=1.20, r=1.3e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 5
#
# t=3.30, r=3e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 6
#
# t=1.74, r=2e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 7
#
# t=1.74, r=2e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 8
#
# t=1.74, r=2e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 9
#
# t=10.02, r=7.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 10
#
# t=10.02, r=7.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 11
#
# t=10.02, r=7.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 12
#
# t=10.02, r=7.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 13
#
# t=10.02, r=7.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 14
#
# t=10.02, r=7.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 15
#
# t=1.74, r=2e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 16
#
# t=1.56, r=1.9e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 17
#
# t=5.58, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 18
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 19
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 20
#
# t=8.10, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 21
#
# t=8.34, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 22
#
# t=8.22, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 23
#
# t=5.88, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 24
#
# t=7.50, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 25
#
# t=9.84, r=5.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 26
#
# t=9.30, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 27
#
# t=5.10, r=3.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 28
#
# t=7.44, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 29
#
# t=8.94, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 30
#
# t=10.02, r=5.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 31
#
# t=7.20, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 32
#
# t=5.82, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 33
#
# t=9.12, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 34
#
# t=9.60, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 35
#
# t=8.70, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 36
#
# t=6.60, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 37
#
# t=5.10, r=3.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 38
#
# t=7.02, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 39
#
# t=9.00, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 40
#
# t=9.18, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 41
#
# t=7.80, r=4.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 42
#
# t=6.78, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 43
#
# t=8.82, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 44
#
# t=8.58, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 45
#
# t=9.24, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 46
#
# t=5.94, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 47
#
# t=9.06, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 48
#
# t=9.78, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 49
#
# t=8.70, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 50
#
# t=8.22, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 51
#
# t=7.92, r=4.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 52
#
# t=9.48, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 53
#
# t=8.28, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 54
#
# t=10.02, r=5.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 55
#
# t=8.40, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 56
#
# t=9.12, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 57
#
# t=9.48, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 58
#
# t=8.28, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 59
#
# t=8.40, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 60
#
# t=5.64, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 61
#
# t=5.46, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 62
#
# t=8.58, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 63
#
# t=7.38, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 64
#
# t=4.80, r=3.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 65
#
# t=6.78, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 66
#
# t=7.98, r=4.7e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 67
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 68
#
# t=9.42, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 69
#
# t=7.86, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 70
#
# t=4.56, r=3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 71
# t=5.94, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 72
#
# t=8.82, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 73
#
# t=4.98, r=3.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 74
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 75
#
# t=8.28, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 76
#
# t=8.16, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 77
#
# t=9.54, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 78
#
# t=8.88, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 79
#
# t=6.66, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 80
#
# t=7.38, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 81
#
# t=4.50, r=2.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 82
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 83
#
# t=7.92, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 84
#
# t=8.34, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 85
#
# t=7.56, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 86
#
# t=8.58, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 87
#
# t=9.00, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 88
#
# t=9.66, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 89
#
# t=9.00, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 90
#
# t=8.22, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 91
#
# t=5.94, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 92
#
# t=7.68, r=4.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 93
#
# t=5.22, r=3.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 94
#
# t=9.24, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 95
#
# t=7.62, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 96
#
# t=9.78, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 97
#
# t=9.96, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 98
#
# t=10.02, r=5.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 99
#
# t=6.66, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 100
#
# t=6.48, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 101
#
# t=8.76, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 102
#
# t=5.34, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 103
#
# t=6.66, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 104
#
# t=6.90, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 105
#
# t=7.20, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 106
#
# t=8.46, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 107
#
# t=8.58, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 108
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 109
#
# t=7.56, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 110
#
# t=9.12, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 111
#
# t=9.12, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 112
#
# t=8.64, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 113
#
# t=7.74, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 114
#
# t=10.02, r=5.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 115
#
# t=8.16, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 116
#
# t=9.00, r=5.2e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 117
#
# t=7.98, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 118
#
# t=9.72, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 119
#
# t=7.98, r=4.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 120
#
# t=6.06, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 121
#
# t=6.18, r=3.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 122
#
# t=9.60, r=5.3e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 123
#
# t=9.60, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 124
#
# t=6.60, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 125
#
# t=8.52, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 126
#
# t=5.88, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 127
#
# t=8.52, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 128
#
# t=9.90, r=5.6e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 129
#
# t=6.00, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 130
#
# t=9.60, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 131
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 132
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 133
#
# t=7.98, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 134
#
# t=5.46, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 135
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 136
#
# t=7.14, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 137
#
# t=6.48, r=4e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 138
#
# t=5.82, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 139
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 140
#
# t=5.22, r=3.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 141
# t=6.54, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 142
#
# t=7.02, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 143
#
# t=6.78, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 144
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 145
#
# t=8.22, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 146
#
# t=5.82, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 147
#
# t=8.22, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 148
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 149
#
# t=7.14, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 150
#
# t=7.80, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 151
#
# t=5.16, r=3.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 152
#
# t=6.60, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 153
#
# t=5.52, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 154
#
# t=7.08, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 155
#
# t=7.80, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 156
#
# t=9.00, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 157
#
# t=5.40, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 158
#
# t=6.24, r=3.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 159
#
# t=9.84, r=5.6e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 160
#
# t=9.06, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 161
#
# t=9.36, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 162
#
# t=6.00, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 163
#
# t=7.32, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 164
#
# t=8.40, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 165
#
# t=7.50, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 166
#
# t=9.96, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 167
#
# t=7.20, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 168
#
# t=7.98, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 169
#
# t=6.54, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 170
#
# t=5.58, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 171
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 172
#
# t=9.72, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 173
#
# t=6.18, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 174
#
# t=7.86, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 175
#
# t=10.02, r=5.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 176
#
# t=5.52, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 177
#
# t=9.60, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 178
#
# t=7.08, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 179
#
# t=8.70, r=4.9e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 180
#
# t=6.30, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 181
#
# t=8.46, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 182
#
# t=8.40, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 183
#
# t=8.04, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 184
#
# t=4.86, r=3.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 185
#
# t=9.18, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 186
#
# t=7.32, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 187
#
# t=5.64, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 188
#
# t=9.66, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 189
#
# t=5.76, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 190
#
# t=8.22, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 191
#
# t=10.02, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 192
#
# t=8.76, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 193
#
# t=8.04, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 194
#
# t=5.76, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 195
#
# t=10.02, r=5.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 196
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 197
#
# t=6.00, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 198
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 199
#
# t=9.60, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 200
#
# t=7.92, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 201
#
# t=7.14, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 202
#
# t=9.24, r=5.3e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 203
#
# t=9.48, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 204
#
# t=10.02, r=5.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 205
#
# t=8.82, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 206
#
# t=6.18, r=3.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 207
#
# t=7.86, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 208
#
# t=8.04, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 209
#
# t=5.52, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 210
#
# t=6.96, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 211
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 212
#
# t=4.86, r=3.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 213
#
# t=6.30, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 214
#
# t=6.42, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 215
#
# t=9.24, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 216
#
# t=8.04, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 217
#
# t=7.56, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 218
#
# t=7.86, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 219
#
# t=9.12, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 220
#
# t=9.54, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 221
#
# t=9.06, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 222
#
# t=6.78, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 223
#
# t=8.94, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 224
#
# t=7.20, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 225
#
# t=7.38, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 226
#
# t=4.98, r=3.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 227
#
# t=4.56, r=3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 228
#
# t=9.06, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 229
#
# t=7.98, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 230
#
# t=10.02, r=5.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 231
#
# t=7.44, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 232
#
# t=8.04, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 233
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 234
#
# t=7.02, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 235
#
# t=9.06, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 236
#
# t=7.02, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 237
#
# t=6.60, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 238
#
# t=8.28, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 239
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 240
#
# t=7.50, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 241
#
# t=6.24, r=3.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 242
#
# t=4.38, r=2.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 243
#
# t=9.12, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 244
#
# t=6.18, r=3.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 245
#
# t=5.46, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 246
#
# t=6.48, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 247
#
# t=8.70, r=5.1e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 248
#
# t=9.42, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 249
#
# t=5.34, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 250
#
# t=5.76, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 251
#
# t=5.94, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 252
#
# t=8.52, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 253
#
# t=5.58, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 254
#
# t=8.76, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 255
#
# t=4.98, r=3.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 256
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 257
#
# t=9.36, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 258
#
# t=8.70, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 259
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 260
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 261
#
# t=7.08, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 262
#
# t=6.18, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 263
#
# t=7.98, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 264
#
# t=9.66, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 265
#
# t=9.72, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 266
#
# t=7.14, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 267
#
# t=5.58, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 268
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 269
#
# t=9.66, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 270
#
# t=7.08, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 271
#
# t=8.22, r=4.7e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 272
#
# t=7.56, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 273
#
# t=9.72, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 274
#
# t=9.06, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 275
#
# t=4.80, r=3.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 276
#
# t=8.64, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 277
#
# t=7.08, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 278
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 279
#
# t=7.08, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 280
#
# t=9.30, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 281
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 282
#
# t=8.46, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 283
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 284
#
# t=5.34, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 285
#
# t=7.26, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 286
#
# t=7.98, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 287
#
# t=9.18, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 288
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 289
#
# t=5.76, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 290
#
# t=8.04, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 291
#
# t=6.18, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 292
#
# t=8.34, r=4.8e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 293
#
# t=9.60, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 294
#
# t=9.96, r=5.5e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 295
#
# t=7.32, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 296
#
# t=5.16, r=3.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 297
#
# t=8.64, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 298
#
# t=6.48, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 299
#
# t=7.20, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 300
#
# t=9.00, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 301
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 302
#
# t=8.76, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 303
#
# t=8.34, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 304
#
# t=8.04, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 305
#
# t=9.06, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 306
#
# t=5.40, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 307
#
# t=9.90, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 308
#
# t=6.90, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 309
#
# t=7.20, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 310
#
# t=9.06, r=5e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 311
#
# t=6.06, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 312
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 313
#
# t=7.86, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 314
#
# t=7.14, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 315
#
# t=9.30, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 316
#
# t=8.04, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 317
#
# t=9.30, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 318
#
# t=7.38, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 319
#
# t=8.64, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 320
#
# t=8.64, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 321
#
# t=7.92, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 322
#
# t=8.70, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 323
#
# t=6.42, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 324
#
# t=8.40, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 325
#
# t=8.64, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 326
#
# t=6.48, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 327
#
# t=7.98, r=4.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 328
#
# t=7.38, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 329
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 330
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 331
#
# t=9.96, r=5.6e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 332
#
# t=8.34, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 333
#
# t=8.34, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 334
#
# t=5.40, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 335
#
# t=6.78, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 336
#
# t=8.88, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 337
#
# t=6.90, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 338
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 339
#
# t=9.12, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 340
#
# t=8.76, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 341
#
# t=9.48, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 342
#
# t=6.84, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 343
#
# t=7.38, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 344
#
# t=8.16, r=4.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 345
#
# t=4.26, r=2.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 346
#
# t=9.54, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 347
#
# t=7.98, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 348
#
# t=5.04, r=3.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 349
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 350
#
# t=8.76, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 351
# t=10.02, r=5.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 352
#
# t=5.10, r=3.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 353
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 354
#
# t=9.06, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 355
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 356
#
# t=8.70, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 357
#
# t=9.00, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 358
#
# t=8.76, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 359
#
# t=7.08, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 360
#
# t=9.60, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 361
#
# t=7.38, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 362
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 363
#
# t=8.10, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 364
#
# t=9.96, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 365
#
# t=7.20, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 366
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 367
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 368
#
# t=6.90, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 369
#
# t=5.46, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 370
#
# t=6.36, r=3.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 371
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 372
#
# t=8.64, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 373
#
# t=7.20, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 374
#
# t=8.16, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 375
#
# t=7.80, r=4.6e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 376
#
# t=7.38, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 377
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 378
#
# t=9.84, r=5.7e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 379
#
# t=8.34, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 380
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 381
#
# t=5.40, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 382
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 383
#
# t=4.56, r=3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 384
#
# t=7.14, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 385
#
# t=10.02, r=5.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 386
#
# t=6.24, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 387
#
# t=8.16, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 388
#
# t=9.30, r=5.3e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 389
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 390
#
# t=7.74, r=4.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 391
#
# t=8.58, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 392
#
# t=7.50, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 393
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 394
#
# t=5.46, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 395
#
# t=9.42, r=5.4e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 396
#
# t=6.42, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 397
#
# t=5.64, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 398
#
# t=5.16, r=3.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 399
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 400
#
# t=8.82, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 401
#
# t=8.94, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 402
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 403
#
# t=10.02, r=5.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 404
#
# t=6.00, r=3.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 405
#
# t=8.04, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 406
#
# t=7.32, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 407
#
# t=6.78, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 408
#
# t=10.02, r=5.4e+02, crash=False
#
# ...
#
# Episode: 865
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 866
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 867
#
# t=9.60, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 868
#
# t=9.96, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 869
#
# t=7.14, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 870
#
# t=8.70, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 871
#
# t=5.10, r=3.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 872
#
# t=10.02, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 873
#
# t=4.74, r=3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 874
#
# t=5.16, r=3.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 875
#
# t=7.14, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 876
#
# t=4.98, r=3.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 877
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 878
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 879
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 880
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 881
#
# t=7.50, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 882
#
# t=7.08, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 883
#
# t=6.72, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 884
#
# t=9.66, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 885
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 886
#
# t=8.76, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 887
#
# t=5.88, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 888
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 889
#
# t=7.32, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 890
#
# t=6.54, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 891
#
# t=6.78, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 892
#
# t=5.64, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 893
#
# t=4.44, r=2.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 894
#
# t=9.00, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 895
#
# t=9.78, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 896
#
# t=9.60, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 897
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 898
#
# t=7.62, r=4.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 899
#
# t=6.42, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 900
#
# t=9.54, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 901
#
# t=5.76, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 902
#
# t=4.98, r=3.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 903
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 904
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 905
#
# t=6.78, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 906
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 907
#
# t=8.34, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 908
#
# t=9.90, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 909
#
# t=7.26, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 910
#
# t=8.70, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 911
# t=7.92, r=4.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 912
#
# t=7.08, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 913
#
# t=7.08, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 914
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 915
#
# t=9.72, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 916
#
# t=5.70, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 917
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 918
#
# t=8.82, r=5.2e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 919
#
# t=7.14, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 920
#
# t=5.58, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 921
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 922
#
# t=8.22, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 923
#
# t=8.58, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 924
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 925
#
# t=8.10, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 926
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 927
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 928
#
# t=8.52, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 929
#
# t=5.58, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 930
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 931
#
# t=9.72, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 932
#
# t=6.48, r=3.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 933
#
# t=8.58, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 934
#
# t=8.40, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 935
#
# t=8.88, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 936
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 937
#
# t=5.70, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 938
#
# t=6.24, r=3.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 939
#
# t=7.38, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 940
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 941
#
# t=6.78, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 942
#
# t=7.86, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 943
#
# t=8.46, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 944
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 945
#
# t=9.12, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 946
#
# t=8.88, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 947
#
# t=9.78, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 948
#
# t=9.84, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 949
#
# t=7.02, r=4.2e+02, crash=True
#
# ______________________________________________________________________
#
# Episode: 950
#
# t=7.86, r=4.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 951
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 952
#
# t=7.68, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 953
#
# t=6.36, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 954
#
# t=5.58, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 955
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 956
#
# t=6.84, r=4.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 957
#
# t=9.84, r=5.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 958
#
# t=8.46, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 959
#
# t=6.48, r=4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 960
#
# t=6.48, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 961
#
# t=9.72, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 962
#
# t=8.88, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 963
#
# t=8.76, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 964
#
# t=7.20, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 965
#
# t=4.20, r=2.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 966
#
# t=5.10, r=3.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 967
#
# t=8.04, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 968
#
# t=7.44, r=4.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 969
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 970
#
# t=6.30, r=3.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 971
#
# t=7.56, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 972
#
# t=6.90, r=4.2e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 973
#
# t=9.24, r=5.1e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 974
#
# t=6.36, r=3.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 975
#
# t=8.94, r=4.9e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 976
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 977
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 978
#
# t=8.88, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 979
#
# t=6.06, r=3.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 980
#
# t=9.48, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 981
# t=6.18, r=3.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 982
#
# t=4.62, r=3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 983
#
# t=7.38, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 984
#
# t=9.12, r=5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 985
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 986
#
# t=5.46, r=3.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 987
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 988
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 989
#
# t=8.46, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 990
#
# t=5.46, r=3.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 991
#
# t=7.62, r=4.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 992
#
# t=8.40, r=4.8e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 993
#
# t=8.22, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 994
#
# t=10.02, r=5.4e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 995
#
# t=10.02, r=5.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 996
#
# t=10.02, r=5.3e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 997
#
# t=5.82, r=3.6e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 998
#
# t=8.34, r=4.7e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 999
#
# t=7.80, r=4.5e+02, crash=False
#
# ______________________________________________________________________
#
# Episode: 1000
#
# t=5.88, r=3.6e+02, crash=False

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
from itertools import islice

def window(seq, n=2):
    "Returns a sliding window (of width n) over data from the iterable"
    "   s -> (s0,s1,...s[n-1]), (s1,s2,...,sn), ...                   "
    it = iter(seq)
    result = tuple(islice(it, n))
    if len(result) == n:
        yield result    
    for elem in it:
        result = result[1:] + (elem,)
        yield result
        
def moving_averages(values, size):
    for selection in window(values, size):
        yield sum(selection) / size

# %%
rewards_rolling_mean = []
for avg in moving_averages(map(int, episode_rewards), 10):
    rewards_rolling_mean.append(avg)

# %%
## TODO: Plot the rewards.
plt.plot(episode_rewards, color='blue', label='reward')
plt.plot(rewards_rolling_mean, color='brown', label='avg reward')
# plt.plot(times, color='green', label='flight time')
# plt.plot(np.invert(crashes), color='red', label='not crashed')
plt.legend()

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:
# The task I gave my agent was simply to hover in the same place over the entire episode time. Thus initial position and target position were the same.
#
# In the reward function I gave a significant penalty for crashing. I also tried rewarding the agent for longer flights without crashing. However, both of these approaches did not yield any significant learning success.
#
# When I modified the reward function given by Udacity and added a `tanh` function, learning results got better. Because `tanh` has the biggest gradient around 0, I tweaked the scalar variable to improve results.
#
# *Update after Review Feedback*
# Incorporated reviewer feedback and rewarded staying close to target as well as penalizing when agent did not stay close to target.
# I think what made a diffference to my previous attempts at defining the reward function was that I ran all parts of the reward through `tanh`.

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:
#
# I've started out with the DDPG agent that was provided by Udacity. This seemed to work out of the box with a few minor adjustments to get it running. The values used are $\gamma$ = 0.99, $\tau$ = 0.01
#
#
# The Critic's neural network is composed of:
#
# - input layer
# - two hidden layers (Dense) with `relu` activation function
# - another two hidden layers (Dense) with `relu` activation function
# - the output layer is another Dense layer

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:
#
# The learning task itself (hovering in the same place) seems not a hard task to accomplish. However, it was hard for me to get my agent to do anything meaningful...  =)
#
# Looking at the rewards plot of rewards and average rewards (over 5 episodes) we can see that the first ~15 episoded have a poor reward. Then there is a steep increase in the reward and the agent manages to keep an average of over 800 for a while. Rewards then drop again as the agent crashes the quadcopter for a number of episodes before again reaching levels of reward of more than 800.
#
# The observations around the reward are quite corelated with the agent crashing the quadcopter.
#
# *Update after Review*
# Changed the number of episodes to 1000. However, I'm not sure this is even needed. Because what I can see from the rewards plot is that the agent very quickly - after approx. 10 episoded - has learned to avoid crashing and collecting rewards continuously.

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
#
# I found this project quite difficult as I didn't really know where to start. Reading posts from others in the Slack channel I started working on the reward function first. I decided to go for a simple task and let the quadcopter hover in the same place.
#
# What I found strange was that sometimes when I had the agent train, it would manage to avoid crashing for many episodes. However, then after continuing some more episodes, it would again start crashing.
# Restarting the entire training process it seemed that my agent would sometimes manage to get on the right path and avoid crashing, and sometimes not. Hence, I had to restart the entire training process several times until the agent showed satisfactory learning behavior.
